# %% [markdown]
# ## Project 1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Read the following dataset

# %%
url1 = "https://raw.githubusercontent.com/jackiekazil/data-wrangling/master/data/chp3/data-text.csv"
df = pd.read_csv(url1)

# %%
df.head(2)
# Out:
#                           Indicator PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %%
url2 = "https://raw.githubusercontent.com/kjam/data-wrangling-pycon/master/data/berlin_weather_oldest.csv"
df1 = pd.read_csv(url2)

# %%
df1.head(2)
# Out:
#              STATION         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
#
#    TMIN  WDFG  PGTM  ...   WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0   -11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 1    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#    WT18  WT03
# 0 -9999 -9999
# 1 -9999 -9999
#
# [2 rows x 21 columns]

# %% [markdown]
# ## Problem 1
#
# Get the Metadata from the above files.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4656 entries, 0 to 4655
# Data columns (total 12 columns):
# Indicator                  4656 non-null object
# PUBLISH STATES             4656 non-null object
# Year                       4656 non-null int64
# WHO region                 4656 non-null object
# World Bank income group    4656 non-null object
# Country                    4656 non-null object
# Sex                        4656 non-null object
# Display Value              4656 non-null int64
# Numeric                    4656 non-null float64
# Low                        0 non-null float64
# High                       0 non-null float64
# Comments                   0 non-null float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 436.6+ KB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117208 entries, 0 to 117207
# Data columns (total 21 columns):
# STATION         117208 non-null object
# STATION_NAME    117208 non-null object
# DATE            117208 non-null int64
# PRCP            117208 non-null int64
# SNWD            117208 non-null int64
# SNOW            117208 non-null int64
# TMAX            117208 non-null int64
# TMIN            117208 non-null int64
# WDFG            117208 non-null int64
# PGTM            117208 non-null int64
# WSFG            117208 non-null int64
# WT09            117208 non-null int64
# WT07            117208 non-null int64
# WT01            117208 non-null int64
# WT06            117208 non-null int64
# WT05            117208 non-null int64
# WT04            117208 non-null int64
# WT16            117208 non-null int64
# WT08            117208 non-null int64
# WT18            117208 non-null int64
# WT03            117208 non-null int64
# dtypes: int64(19), object(2)
# ...

# %% [markdown]
# ## Problem 2
#
# Get the row names from the above files.

# %%
df.index.get_values()
# Out:
# array([   0,    1,    2, ..., 4653, 4654, 4655], dtype=int64)

# %%
df1.index.get_values()
# Out:
# array([     0,      1,      2, ..., 117205, 117206, 117207], dtype=int64)

# %% [markdown]
# ## Problem 3
#
# Change the column name from any of the above file.

# %%
df = df.rename(columns = {'Indicator': 'Indicator_Id'})

# %%
df.head(5)
# Out:
#                         Indicator_Id PUBLISH STATES  Year  \
# 0   Life expectancy at birth (years)      Published  1990
# 1   Life expectancy at birth (years)      Published  2000
# 2  Life expectancy at age 60 (years)      Published  2012
# 3  Life expectancy at age 60 (years)      Published  2000
# 4   Life expectancy at birth (years)      Published  2012
#
#               WHO region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# 3                 Europe             High-income               Andorra
# 4  Eastern Mediterranean             High-income  United Arab Emirates
#
#           Sex  Display Value  Numeric  Low  High  Comments
# 0  Both sexes             77     77.0  NaN   NaN       NaN
# 1  Both sexes             80     80.0  NaN   NaN       NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4656 entries, 0 to 4655
# Data columns (total 12 columns):
# Indicator_Id               4656 non-null object
# PUBLISH STATES             4656 non-null object
# Year                       4656 non-null int64
# WHO region                 4656 non-null object
# World Bank income group    4656 non-null object
# Country                    4656 non-null object
# Sex                        4656 non-null object
# Display Value              4656 non-null int64
# Numeric                    4656 non-null float64
# Low                        0 non-null float64
# High                       0 non-null float64
# Comments                   0 non-null float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 436.6+ KB

# %% [markdown]
# ## Problem 4
#
# Change the column name from any of the above file and store the changes made permanently.

# %%
df.rename(columns = {'Indicator': 'Indicator_Id'}, inplace = True)

# %%
df.head(5)
# Out:
#                         Indicator_Id PUBLISH STATES  Year  \
# 0   Life expectancy at birth (years)      Published  1990
# 1   Life expectancy at birth (years)      Published  2000
# 2  Life expectancy at age 60 (years)      Published  2012
# 3  Life expectancy at age 60 (years)      Published  2000
# 4   Life expectancy at birth (years)      Published  2012
#
#               WHO region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# 3                 Europe             High-income               Andorra
# 4  Eastern Mediterranean             High-income  United Arab Emirates
#
#           Sex  Display Value  Numeric  Low  High  Comments
# 0  Both sexes             77     77.0  NaN   NaN       NaN
# 1  Both sexes             80     80.0  NaN   NaN       NaN
# ...

# %% [markdown]
# ## Problem 5
#
# Change the names of multiple columns.

# %%
df.rename(columns = {'PUBLISH STATES': 'Publication Status', 'WHO region':'WHO Region'}, inplace = True)

# %%
df.head(5)
# Out:
#                         Indicator_Id Publication Status  Year  \
# 0   Life expectancy at birth (years)          Published  1990
# 1   Life expectancy at birth (years)          Published  2000
# 2  Life expectancy at age 60 (years)          Published  2012
# 3  Life expectancy at age 60 (years)          Published  2000
# 4   Life expectancy at birth (years)          Published  2012
#
#               WHO Region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# 3                 Europe             High-income               Andorra
# 4  Eastern Mediterranean             High-income  United Arab Emirates
#
#           Sex  Display Value  Numeric  Low  High  Comments
# 0  Both sexes             77     77.0  NaN   NaN       NaN
# ...

# %% [markdown]
# ## Problem 6
#
# Arrange values of a particular column in ascending order.

# %%
df.sort_values(by = 'Year', axis = 0, ascending = True, inplace = True)

# %%
df.head(10)
# Out:
#                            Indicator_Id Publication Status  Year  \
# 0      Life expectancy at birth (years)          Published  1990
# 1270   Life expectancy at birth (years)          Published  1990
# 3193   Life expectancy at birth (years)          Published  1990
# 3194   Life expectancy at birth (years)          Published  1990
# 3197  Life expectancy at age 60 (years)          Published  1990
# 1264   Life expectancy at birth (years)          Published  1990
# 3199  Life expectancy at age 60 (years)          Published  1990
# 1262  Life expectancy at age 60 (years)          Published  1990
# 1259   Life expectancy at birth (years)          Published  1990
# 3203  Life expectancy at age 60 (years)          Published  1990
#
#            WHO Region World Bank income group              Country  \
# 0              Europe             High-income              Andorra
# 1270           Europe             High-income              Germany
# ...

# %% [markdown]
# ## Problem 7
#
# Arrange multiple column values in ascending order.

# %%
df.sort_values(by = ['Indicator_Id','Country','Year' ,'WHO Region','Publication Status'], axis = 0, \
               ascending = [False,True,True,False,False], inplace = True)

# %%
df.head(10)
# Out:
#                           Indicator_Id Publication Status  Year  \
# 554   Life expectancy at birth (years)          Published  1990
# 965   Life expectancy at birth (years)          Published  1990
# 1792  Life expectancy at birth (years)          Published  1990
# 146   Life expectancy at birth (years)          Published  2000
# 1393  Life expectancy at birth (years)          Published  2000
# 2957  Life expectancy at birth (years)          Published  2000
# 966   Life expectancy at birth (years)          Published  2012
# 1394  Life expectancy at birth (years)          Published  2012
# 2958  Life expectancy at birth (years)          Published  2012
# 299   Life expectancy at birth (years)          Published  1990
#
#                  WHO Region World Bank income group      Country         Sex  \
# 554   Eastern Mediterranean              Low-income  Afghanistan  Both sexes
# 965   Eastern Mediterranean              Low-income  Afghanistan        Male
# ...

# %% [markdown]
# ## Problem 8
#
# Make country as the first column of the dataframe.

# %%
cols = df.columns.values

# %%
cols
# Out:
# array(['Indicator_Id', 'Publication Status', 'Year', 'WHO Region',
#        'World Bank income group', 'Country', 'Sex', 'Display Value',
#        'Numeric', 'Low', 'High', 'Comments'], dtype=object)

# %%
df = df[['Country', 'Indicator_Id', 'Publication Status', 'Year', 'WHO Region',
       'World Bank income group', 'Sex', 'Display Value',
       'Numeric', 'Low', 'High', 'Comments']]

# %%
df.head(10)
# Out:
#                 Country                       Indicator_Id Publication Status  \
# 0               Andorra   Life expectancy at birth (years)          Published
# 1               Andorra   Life expectancy at birth (years)          Published
# 2               Andorra  Life expectancy at age 60 (years)          Published
# 3               Andorra  Life expectancy at age 60 (years)          Published
# 4  United Arab Emirates   Life expectancy at birth (years)          Published
# 5   Antigua and Barbuda   Life expectancy at birth (years)          Published
# 6   Antigua and Barbuda  Life expectancy at age 60 (years)          Published
# 7   Antigua and Barbuda  Life expectancy at age 60 (years)          Published
# 8             Australia   Life expectancy at birth (years)          Published
# 9             Australia   Life expectancy at birth (years)          Published
#
#    Year             WHO Region World Bank income group         Sex  \
# ...

# %% [markdown]
# ## Problem 9
#
# Get the column array using a variable.

# %%
colarray = df['Country']

# %%
colarray.get_values()
# Out:
# array(['Andorra', 'Andorra', 'Andorra', ..., 'South Africa', 'Zambia',
#        'Zimbabwe'], dtype=object)

# %% [markdown]
# ## Problem 10
#
# Get the subset rows 11, 24, 37.

# %%
df.loc[[11,24,37]]
# Out:
#               Country                       Indicator_Id Publication Status  \
# 11            Austria   Life expectancy at birth (years)          Published
# 24  Brunei Darussalam  Life expectancy at age 60 (years)          Published
# 37             Cyprus  Life expectancy at age 60 (years)          Published
#
#     Year       WHO Region World Bank income group     Sex  Display Value  \
# 11  2012           Europe             High-income  Female             83
# 24  2012  Western Pacific             High-income  Female             21
# 37  2012           Europe             High-income  Female             26
#
#     Numeric  Low  High  Comments
# 11     83.0  NaN   NaN       NaN
# 24     21.0  NaN   NaN       NaN
# 37     26.0  NaN   NaN       NaN

# %% [markdown]
# ## Problem 11
#
# Get the subset rows excluding 5, 12, 23, and 56.

# %%
df_exclude_rows = df.index.isin([5,12,23,56])

# %%
df[~df_exclude_rows]
# Out:
#                                  Country  \
# 0                                Andorra
# 1                                Andorra
# 2                                Andorra
# 3                                Andorra
# 4                   United Arab Emirates
# 6                    Antigua and Barbuda
# 7                    Antigua and Barbuda
# 8                              Australia
# 9                              Australia
# 10                             Australia
# 11                               Austria
# 13                               Belgium
# 14                               Bahrain
# 15                               Bahrain
# 16                               Bahrain
# 17                               Bahamas
# 18                               Bahamas
# 19                              Barbados
# 20                              Barbados
# 21                              Barbados
# 22                     Brunei Darussalam
# 24                     Brunei Darussalam
# ...

# %% [markdown]
# ## Load datasets from CSV

# %%
url3 = "https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/users.csv"
users = pd.read_csv(url3)

# %%
url4 = "https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/sessions.csv"
sessions = pd.read_csv(url4)

# %%
url5 = "https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/products.csv"
products = pd.read_csv(url5)

# %%
url6 = "https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/transactions.csv"
transactions = pd.read_csv(url6)

# %%
transactions
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 1              2      2011-05-26     3.0          4         1
# 2              3      2011-06-16     3.0          3         1
# 3              4      2012-08-26     1.0          2         3
# 4              5      2013-06-06     2.0          4         1
# 5              6      2013-12-23     2.0          5         6
# 6              7      2013-12-30     3.0          4         1
# 7              8      2014-04-24     NaN          2         3
# 8              9      2015-04-24     7.0          4         3
# 9             10      2016-05-08     3.0          4         4

# %%
users
# Out:
#    UserID      User  Gender  Registered   Cancelled
# 0       1   Charles    male  2012-12-21         NaN
# 1       2     Pedro    male  2010-08-01  2010-08-08
# 2       3  Caroline  female  2012-10-23  2016-06-07
# 3       4   Brielle  female  2013-07-17         NaN
# 4       5  Benjamin    male  2010-11-25         NaN

# %%
sessions
# Out:
#    SessionID SessionDate  UserID
# 0          1  2010-01-05       2
# 1          2  2010-08-01       2
# 2          3  2010-11-25       2
# 3          4  2011-09-21       5
# 4          5  2011-10-19       4
# 5          6  2012-10-23       4
# 6          7  2012-12-21       3
# 7          8  2013-05-22       4
# 8          9  2013-07-17       4
# 9         10  2016-01-11       4

# %%
products
# Out:
#    ProductID Product  Price
# 0          1       A  14.16
# 1          2       B  33.04
# 2          3       C  10.65
# 3          4       D  10.02
# 4          5       E  29.66

# %% [markdown]
# ## Problem 12
#
# Join users to transactions, keeping all rows from transactions and only matching rows from users (left join).

# %%
transactions_by_user = pd.merge(transactions, users, how = 'left', on = 'UserID')

# %%
transactions_by_user
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              1      2010-08-21     7.0          2         1       NaN
# 1              2      2011-05-26     3.0          4         1  Caroline
# 2              3      2011-06-16     3.0          3         1  Caroline
# 3              4      2012-08-26     1.0          2         3   Charles
# 4              5      2013-06-06     2.0          4         1     Pedro
# 5              6      2013-12-23     2.0          5         6     Pedro
# 6              7      2013-12-30     3.0          4         1  Caroline
# 7              8      2014-04-24     NaN          2         3       NaN
# 8              9      2015-04-24     7.0          4         3       NaN
# 9             10      2016-05-08     3.0          4         4  Caroline
#
#    Gender  Registered   Cancelled
# 0     NaN         NaN         NaN
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 3    male  2012-12-21         NaN
# ...

# %% [markdown]
# ## Problem 13
#
# Which transactions have a UserID not in users.

# %%
trans_with_no_userid = transactions['UserID'].isin(users['UserID'])

# %%
transactions[~trans_with_no_userid]
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 7              8      2014-04-24     NaN          2         3
# 8              9      2015-04-24     7.0          4         3

# %% [markdown]
# ## Problem 14
#
# Join users to transactions, keeping only rows from transactions and users that match via UserID (inner join).

# %%
transactions_with_valid_user = pd.merge(transactions, users, how = 'inner', on = 'UserID')

# %%
transactions_with_valid_user
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              2      2011-05-26     3.0          4         1  Caroline
# 1              3      2011-06-16     3.0          3         1  Caroline
# 2              7      2013-12-30     3.0          4         1  Caroline
# 3             10      2016-05-08     3.0          4         4  Caroline
# 4              4      2012-08-26     1.0          2         3   Charles
# 5              5      2013-06-06     2.0          4         1     Pedro
# 6              6      2013-12-23     2.0          5         6     Pedro
#
#    Gender  Registered   Cancelled
# 0  female  2012-10-23  2016-06-07
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 3  female  2012-10-23  2016-06-07
# 4    male  2012-12-21         NaN
# 5    male  2010-08-01  2010-08-08
# 6    male  2010-08-01  2010-08-08

# %% [markdown]
# ## Problem 15
#
# Join users to transactions, displaying all matching rows AND all non-matching rows (full outer join).

# %%
all_transaction_matching_nonmatching = pd.merge(transactions, users, how = 'outer')

# %%
all_transaction_matching_nonmatching
# Out:
#     TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0             1.0      2010-08-21     7.0        2.0       1.0       NaN
# 1             9.0      2015-04-24     7.0        4.0       3.0       NaN
# 2             2.0      2011-05-26     3.0        4.0       1.0  Caroline
# 3             3.0      2011-06-16     3.0        3.0       1.0  Caroline
# 4             7.0      2013-12-30     3.0        4.0       1.0  Caroline
# 5            10.0      2016-05-08     3.0        4.0       4.0  Caroline
# 6             4.0      2012-08-26     1.0        2.0       3.0   Charles
# 7             5.0      2013-06-06     2.0        4.0       1.0     Pedro
# 8             6.0      2013-12-23     2.0        5.0       6.0     Pedro
# 9             8.0      2014-04-24     NaN        2.0       3.0       NaN
# 10            NaN             NaN     4.0        NaN       NaN   Brielle
# 11            NaN             NaN     5.0        NaN       NaN  Benjamin
#
# ...

# %% [markdown]
# ## Problem 16
#
# Determine which sessions occurred on the same day each user registered.

# %%
sessions_date_user_registered = pd.merge(left=users, left_on=['UserID', 'Registered'],\
                                         right= sessions, right_on=['UserID', 'SessionDate'], how='inner')

# %%
sessions_date_user_registered
# Out:
#    UserID     User  Gender  Registered   Cancelled  key  SessionID SessionDate
# 0       2    Pedro    male  2010-08-01  2010-08-08    0          2  2010-08-01
# 1       4  Brielle  female  2013-07-17         NaN    0          9  2013-07-17

# %% [markdown]
# ## Problem 17
#
# Build a dataset with every possible (UserID, ProductID) pair (cross join).

# %%
users1 = pd.DataFrame({'key': (users.shape[0]), 'UserID': users.UserID})
products1 = pd.DataFrame({'key': (products.shape[0]), 'ProductID': products.ProductID})
userid_prodid_pair = pd.merge(users1, products1, on='key')[['UserID', 'ProductID']]

# %%
userid_prodid_pair
# Out:
#     UserID  ProductID
# 0        1          1
# 1        1          2
# 2        1          3
# 3        1          4
# 4        1          5
# 5        2          1
# 6        2          2
# 7        2          3
# 8        2          4
# 9        2          5
# 10       3          1
# 11       3          2
# 12       3          3
# 13       3          4
# 14       3          5
# 15       4          1
# 16       4          2
# 17       4          3
# 18       4          4
# 19       4          5
# 20       5          1
# 21       5          2
# 22       5          3
# 23       5          4
# 24       5          5

# %% [markdown]
# ## Problem 18
#
# Determine how much quantity of each product was purchased by each user

# %%
qty_product_user = pd.merge( userid_prodid_pair, transactions, how='left', on=['UserID','ProductID']) \
                           [['UserID', 'ProductID', 'Quantity']].fillna(0)

# %%
qty_product_user
# Out:
#     UserID  ProductID  Quantity
# 0        1          1       0.0
# 1        1          2       3.0
# 2        1          3       0.0
# 3        1          4       0.0
# 4        1          5       0.0
# 5        2          1       0.0
# 6        2          2       0.0
# 7        2          3       0.0
# 8        2          4       1.0
# 9        2          5       6.0
# 10       3          1       0.0
# 11       3          2       0.0
# 12       3          3       1.0
# 13       3          4       1.0
# 14       3          4       1.0
# 15       3          4       4.0
# 16       3          5       0.0
# 17       4          1       0.0
# 18       4          2       0.0
# 19       4          3       0.0
# 20       4          4       0.0
# 21       4          5       0.0
# 22       5          1       0.0
# 23       5          2       0.0
# 24       5          3       0.0
# 25       5          4       0.0
# 26       5          5       0.0

# %% [markdown]
# ## Problem 19
#
# For each user, get each possible pair of pair transactions (TransactionID1, TransacationID2).

# %%
pair_transaction_by_user = pd.merge(transactions, transactions, how= 'inner', on='UserID')

# %%
pair_transaction_by_user
# Out:
#     TransactionID_x TransactionDate_x  UserID  ProductID_x  Quantity_x  \
# 0                 1        2010-08-21     7.0            2           1
# 1                 1        2010-08-21     7.0            2           1
# 2                 9        2015-04-24     7.0            4           3
# 3                 9        2015-04-24     7.0            4           3
# 4                 2        2011-05-26     3.0            4           1
# 5                 2        2011-05-26     3.0            4           1
# 6                 2        2011-05-26     3.0            4           1
# 7                 2        2011-05-26     3.0            4           1
# 8                 3        2011-06-16     3.0            3           1
# 9                 3        2011-06-16     3.0            3           1
# 10                3        2011-06-16     3.0            3           1
# 11                3        2011-06-16     3.0            3           1
# ...

# %% [markdown]
# ## Problem 20
#
# Join each user to his/her first occuring transaction in the transactions table.

# %%
user_by_transaction = pd.merge(users, transactions.groupby('UserID').first(), how='left', on='UserID').drop('key', axis=1)

# %%
user_by_transaction
# Out:
#    UserID      User  Gender  Registered   Cancelled  TransactionID  \
# 0       1   Charles    male  2012-12-21         NaN            4.0
# 1       2     Pedro    male  2010-08-01  2010-08-08            5.0
# 2       3  Caroline  female  2012-10-23  2016-06-07            2.0
# 3       4   Brielle  female  2013-07-17         NaN            NaN
# 4       5  Benjamin    male  2010-11-25         NaN            NaN
#
#   TransactionDate  ProductID  Quantity
# 0      2012-08-26        2.0       3.0
# 1      2013-06-06        4.0       1.0
# 2      2011-05-26        4.0       1.0
# 3             NaN        NaN       NaN
# 4             NaN        NaN       NaN

# %% [markdown]
# ## Problem 21
#
# Test to see if we can drop columns.

# %%
my_columns = list(user_by_transaction.columns)

# %%
my_columns
# Out:
# ['UserID',
#  'User',
#  'Gender',
#  'Registered',
#  'Cancelled',
#  'TransactionID',
#  'TransactionDate',
#  'ProductID',
#  'Quantity']

# %%
list(user_by_transaction.dropna(thresh=int(user_by_transaction.shape[0]*.9), axis=1).columns)
# Out:
# ['UserID', 'User', 'Gender', 'Registered']

# %%
missing_info = list(user_by_transaction.columns[user_by_transaction.isnull().any()])

# %%
missing_info
# Out:
# ['Cancelled', 'TransactionID', 'TransactionDate', 'ProductID', 'Quantity']

# %%
for col in missing_info:
    num_missing = user_by_transaction[user_by_transaction[col].isnull() == True].shape[0]
    print('number missing for column {}: {}'.format(col, num_missing))
# Out:
# number missing for column Cancelled: 3
# number missing for column TransactionID: 2
# number missing for column TransactionDate: 2
# number missing for column ProductID: 2
# number missing for column Quantity: 2

# %%
for col in missing_info:
    percent_missing = user_by_transaction[user_by_transaction[col].isnull() == True].shape[0]/user_by_transaction.shape[0]
    print('percent missing for column {}: {} percent'.format(col,percent_missing))
# Out:
# percent missing for column Cancelled: 0.6 percent
# percent missing for column TransactionID: 0.4 percent
# percent missing for column TransactionDate: 0.4 percent
# percent missing for column ProductID: 0.4 percent
# percent missing for column Quantity: 0.4 percent
